# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
h = 0.1  # step size
x_start, x_end = 0, 10
num_steps = int((x_end - x_start) / h)
x_values = np.linspace(x_start, x_end, num_steps + 1)
y_values = np.zeros(num_steps + 1)

# Initial condition
y_values[0] = 1  # y(0) = 1

# Function representing dy/dx = -2y
def f(x, y):
    return -2 * y

# Implement Euler's method
for i in range(num_steps):
    y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])

# Plot the results
plt.plot(x_values, y_values, label="Euler's Method Approximation")
plt.xlabel('x')
plt.ylabel('y')
plt.title("Approximation of dy/dx = -2y using Euler's Method")
plt.legend()
plt.show()

# %%
def exact_solution(x):
    return np.exp(-2 * x)

def local_error(x, y_approx):
    return np.abs(exact_solution(x) - y_approx)

def global_error(x, y_approx):
    return np.max(local_error(x, y_approx))

for h in [0.1, 0.5, 1, 1.5]:
    n = int((x_end - x_start) / h)
    x = np.linspace(x_start, x_end, n + 1)
    y = np.zeros(n + 1)
    y[0] = 1
    for i in range(n):
        y[i + 1] = y[i] + h * f(x[i], y[i])
    print(f"h={h}  global error={global_error(x, y):.4f}")
    plt.plot(x, local_error(x, y), label=f"h={h}")

plt.xlabel('x')
plt.ylabel('Local Error')
plt.title('Local Error for Different Step Sizes')
plt.legend()
plt.show()
# Out:
# h=0.1  global error=0.0402
# h=0.5  global error=0.3679
# h=1  global error=1.1353
# h=1.5  global error=64.0000
