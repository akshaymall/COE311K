# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_start, x_end = 0, 2
 
def f(x, y):
    return -2 * y

# %%
h_ref = 0.01
num_steps_ref = int((x_end - x_start) / h_ref)
x_ref = np.linspace(x_start, x_end, num_steps_ref + 1)
y_ref = np.zeros(num_steps_ref + 1)
y_ref[0] = 1
for i in range(num_steps_ref):
    y_ref[i + 1] = y_ref[i] + h_ref * f(x_ref[i], y_ref[i])

# %%
for h in np.arange(0.01, 1.01, 0.05):
    
    num_steps = int((x_end - x_start) / h)
    x_values = np.linspace(x_start, x_end, num_steps + 1)
    y_values = np.zeros(num_steps + 1)
    y_values[0] = 1  # y(0) = 1
    
    for i in range(num_steps):
        y_values[i + 1] = y_values[i] + h * f(x_values[i], y_values[i])
        
    plt.plot(x_values, y_values, label="h " + f"{h:.2f}")
    
    y_ref_interp = np.interp(x_values, x_ref, y_ref)
    point_errors = np.abs(y_values - y_ref_interp)
    total_error = np.sum(point_errors)
 
    print(f"\nh={h:.2f}  |  Total accumulated error: {total_error:.6f}")
    for i in range(len(x_values)):
        print(f"  x={x_values[i]:.3f}  error={point_errors[i]:.8f}")

plt.xlabel('x')
plt.ylabel('y')
plt.title("Approximation of dy/dx = -2y using Euler's Method")
plt.legend(fontsize=6, ncol=2)
plt.show()
# Out:
# h=0.01  |  Total accumulated error: 0.000000
#   x=0.000  error=0.00000000
#   x=0.010  error=0.00000000
#   x=0.020  error=0.00000000
#   x=0.030  error=0.00000000
#   x=0.040  error=0.00000000
#   x=0.050  error=0.00000000
#   x=0.060  error=0.00000000
#   x=0.070  error=0.00000000
#   x=0.080  error=0.00000000
#   x=0.090  error=0.00000000
#   x=0.100  error=0.00000000
#   x=0.110  error=0.00000000
#   x=0.120  error=0.00000000
#   x=0.130  error=0.00000000
#   x=0.140  error=0.00000000
#   x=0.150  error=0.00000000
#   x=0.160  error=0.00000000
#   x=0.170  error=0.00000000
#   x=0.180  error=0.00000000
#   x=0.190  error=0.00000000
#   x=0.200  error=0.00000000
#   x=0.210  error=0.00000000
#   x=0.220  error=0.00000000
#   x=0.230  error=0.00000000
#   x=0.240  error=0.00000000
#   x=0.250  error=0.00000000
#   x=0.260  error=0.00000000
#   x=0.270  error=0.00000000
#   x=0.280  error=0.00000000
#   x=0.290  error=0.00000000
#   x=0.300  error=0.00000000
#   x=0.310  error=0.00000000
#   x=0.320  error=0.00000000
#   x=0.330  error=0.00000000
#   x=0.340  error=0.00000000
#   x=0.350  error=0.00000000
#   x=0.360  error=0.00000000
#   x=0.370  error=0.00000000
#   x=0.380  error=0.00000000
#   x=0.390  error=0.00000000
#   x=0.400  error=0.00000000
#   x=0.410  error=0.00000000
#   x=0.420  error=0.00000000
#   x=0.430  error=0.00000000
#   x=0.440  error=0.00000000
#   x=0.450  error=0.00000000
#   x=0.460  error=0.00000000
#   x=0.470  error=0.00000000
#   x=0.480  error=0.00000000
#   x=0.490  error=0.00000000
#   x=0.500  error=0.00000000
#   x=0.510  error=0.00000000
#   x=0.520  error=0.00000000
#   x=0.530  error=0.00000000
#   x=0.540  error=0.00000000
#   x=0.550  error=0.00000000
#   x=0.560  error=0.00000000
#   x=0.570  error=0.00000000
#   x=0.580  error=0.00000000
#   x=0.590  error=0.00000000
#   x=0.600  error=0.00000000
#   x=0.610  error=0.00000000
#   x=0.620  error=0.00000000
#   x=0.630  error=0.00000000
#   x=0.640  error=0.00000000
#   x=0.650  error=0.00000000
#   x=0.660  error=0.00000000
#   x=0.670  error=0.00000000
#   x=0.680  error=0.00000000
#   x=0.690  error=0.00000000
#   x=0.700  error=0.00000000
#   x=0.710  error=0.00000000
#   x=0.720  error=0.00000000
#   x=0.730  error=0.00000000
#   x=0.740  error=0.00000000
#   x=0.750  error=0.00000000
#   x=0.760  error=0.00000000
#   x=0.770  error=0.00000000
#   x=0.780  error=0.00000000
#   x=0.790  error=0.00000000
#   x=0.800  error=0.00000000
#   x=0.810  error=0.00000000
#   x=0.820  error=0.00000000
#   x=0.830  error=0.00000000
#   x=0.840  error=0.00000000
#   x=0.850  error=0.00000000
#   x=0.860  error=0.00000000
#   x=0.870  error=0.00000000
#   x=0.880  error=0.00000000
#   x=0.890  error=0.00000000
#   x=0.900  error=0.00000000
#   x=0.910  error=0.00000000
#   x=0.920  error=0.00000000
#   x=0.930  error=0.00000000
#   x=0.940  error=0.00000000
#   x=0.950  error=0.00000000
#   x=0.960  error=0.00000000
#   x=0.970  error=0.00000000
#   x=0.980  error=0.00000000
#   x=0.990  error=0.00000000
#   x=1.000  error=0.00000000
#   x=1.010  error=0.00000000
#   x=1.020  error=0.00000000
#   x=1.030  error=0.00000000
#   x=1.040  error=0.00000000
#   x=1.050  error=0.00000000
#   x=1.060  error=0.00000000
#   x=1.070  error=0.00000000
#   x=1.080  error=0.00000000
#   x=1.090  error=0.00000000
#   x=1.100  error=0.00000000
#   x=1.110  error=0.00000000
#   x=1.120  error=0.00000000
#   x=1.130  error=0.00000000
#   x=1.140  error=0.00000000
#   x=1.150  error=0.00000000
#   x=1.160  error=0.00000000
#   x=1.170  error=0.00000000
#   x=1.180  error=0.00000000
#   x=1.190  error=0.00000000
#   x=1.200  error=0.00000000
#   x=1.210  error=0.00000000
#   x=1.220  error=0.00000000
#   x=1.230  error=0.00000000
#   x=1.240  error=0.00000000
#   x=1.250  error=0.00000000
#   x=1.260  error=0.00000000
#   x=1.270  error=0.00000000
#   x=1.280  error=0.00000000
#   x=1.290  error=0.00000000
#   x=1.300  error=0.00000000
#   x=1.310  error=0.00000000
#   x=1.320  error=0.00000000
#   x=1.330  error=0.00000000
#   x=1.340  error=0.00000000
#   x=1.350  error=0.00000000
#   x=1.360  error=0.00000000
#   x=1.370  error=0.00000000
#   x=1.380  error=0.00000000
#   x=1.390  error=0.00000000
#   x=1.400  error=0.00000000
#   x=1.410  error=0.00000000
#   x=1.420  error=0.00000000
#   x=1.430  error=0.00000000
#   x=1.440  error=0.00000000
#   x=1.450  error=0.00000000
#   x=1.460  error=0.00000000
#   x=1.470  error=0.00000000
#   x=1.480  error=0.00000000
#   x=1.490  error=0.00000000
#   x=1.500  error=0.00000000
#   x=1.510  error=0.00000000
#   x=1.520  error=0.00000000
#   x=1.530  error=0.00000000
#   x=1.540  error=0.00000000
#   x=1.550  error=0.00000000
#   x=1.560  error=0.00000000
#   x=1.570  error=0.00000000
#   x=1.580  error=0.00000000
#   x=1.590  error=0.00000000
#   x=1.600  error=0.00000000
#   x=1.610  error=0.00000000
#   x=1.620  error=0.00000000
#   x=1.630  error=0.00000000
#   x=1.640  error=0.00000000
#   x=1.650  error=0.00000000
#   x=1.660  error=0.00000000
#   x=1.670  error=0.00000000
#   x=1.680  error=0.00000000
#   x=1.690  error=0.00000000
#   x=1.700  error=0.00000000
#   x=1.710  error=0.00000000
#   x=1.720  error=0.00000000
#   x=1.730  error=0.00000000
#   x=1.740  error=0.00000000
#   x=1.750  error=0.00000000
#   x=1.760  error=0.00000000
#   x=1.770  error=0.00000000
#   x=1.780  error=0.00000000
#   x=1.790  error=0.00000000
#   x=1.800  error=0.00000000
#   x=1.810  error=0.00000000
#   x=1.820  error=0.00000000
#   x=1.830  error=0.00000000
#   x=1.840  error=0.00000000
#   x=1.850  error=0.00000000
#   x=1.860  error=0.00000000
#   x=1.870  error=0.00000000
#   x=1.880  error=0.00000000
#   x=1.890  error=0.00000000
#   x=1.900  error=0.00000000
#   x=1.910  error=0.00000000
#   x=1.920  error=0.00000000
#   x=1.930  error=0.00000000
#   x=1.940  error=0.00000000
#   x=1.950  error=0.00000000
#   x=1.960  error=0.00000000
#   x=1.970  error=0.00000000
#   x=1.980  error=0.00000000
#   x=1.990  error=0.00000000
#   x=2.000  error=0.00000000
#
# h=0.06  |  Total accumulated error: 0.317266
#   x=0.000  error=0.00000000
#   x=0.061  error=0.00476863
#   x=0.121  error=0.00841438
#   x=0.182  error=0.01113557
#   x=0.242  error=0.01309937
#   x=0.303  error=0.01444644
#   x=0.364  error=0.01529476
#   x=0.424  error=0.01574313
#   x=0.485  error=0.01587395
#   x=0.545  error=0.01575579
#   x=0.606  error=0.01544546
#   x=0.667  error=0.01498986
#   x=0.727  error=0.01442748
#   x=0.788  error=0.01378979
#   x=0.848  error=0.01310232
#   x=0.909  error=0.01238562
#   x=0.970  error=0.01165610
#   x=1.030  error=0.01092826
#   x=1.091  error=0.01021165
#   x=1.152  error=0.00951235
#   x=1.212  error=0.00883622
#   x=1.273  error=0.00818748
#   x=1.333  error=0.00756906
#   x=1.394  error=0.00698281
#   x=1.455  error=0.00642971
#   x=1.515  error=0.00591010
#   x=1.576  error=0.00542373
#   x=1.636  error=0.00497000
#   x=1.697  error=0.00454795
#   x=1.758  error=0.00415641
#   x=1.818  error=0.00379404
#   x=1.879  error=0.00345940
#   x=1.939  error=0.00315099
#   x=2.000  error=0.00286726
#
# h=0.11  |  Total accumulated error: 0.398828
#   x=0.000  error=0.00000000
#   x=0.111  error=0.01895195
#   x=0.222  error=0.02992105
#   x=0.333  error=0.03543077
#   x=0.444  error=0.03729508
#   x=0.556  error=0.03680555
#   x=0.667  error=0.03487111
#   x=0.778  error=0.03212206
#   x=0.889  error=0.02898716
#   x=1.000  error=0.02575063
#   x=1.111  error=0.02259889
#   x=1.222  error=0.01963480
#   x=1.333  error=0.01691883
#   x=1.444  error=0.01447767
#   x=1.556  error=0.01231579
#   x=1.667  error=0.01042362
#   x=1.778  error=0.00878326
#   x=1.889  error=0.00737240
#   x=2.000  error=0.00616698
#
# h=0.16  |  Total accumulated error: 0.349830
#   x=0.000  error=0.00000000
#   x=0.167  error=0.03414708
#   x=0.333  error=0.04758277
#   x=0.500  error=0.04973768
#   x=0.667  error=0.04625696
#   x=0.833  error=0.04032691
#   x=1.000  error=0.03375207
#   x=1.167  error=0.02747998
#   x=1.333  error=0.02191737
#   x=1.500  error=0.01720892
#   x=1.667  error=0.01335123
#   x=1.833  error=0.01025546
#   x=2.000  error=0.00781317
#
# h=0.21  |  Total accumulated error: 0.363045
#   x=0.000  error=0.00000000
#   x=0.222  error=0.05832105
#   x=0.444  error=0.07104564
#   x=0.667  error=0.06495872
#   x=0.889  error=0.05283364
#   x=1.111  error=0.04032098
#   x=1.333  error=0.02956500
#   x=1.556  error=0.02109087
#   x=1.778  error=0.01474908
#   x=2.000  error=0.01016029
#
# h=0.26  |  Total accumulated error: 0.340153
#   x=0.000  error=0.00000000
#   x=0.286  error=0.08148502
#   x=0.571  error=0.08484173
#   x=0.857  error=0.06640564
#   x=1.143  error=0.04629237
#   x=1.429  error=0.03031433
#   x=1.714  error=0.01909652
#   x=2.000  error=0.01171726
#
# h=0.31  |  Total accumulated error: 0.411327
#   x=0.000  error=0.00000000
#   x=0.333  error=0.12998277
#   x=0.667  error=0.11567072
#   x=1.000  error=0.07774756
#   x=1.333  error=0.04678233
#   x=1.667  error=0.02656695
#   x=2.000  error=0.01457701
#
# h=0.36  |  Total accumulated error: 0.401717
#   x=0.000  error=0.00000000
#   x=0.400  error=0.16570040
#   x=0.800  error=0.12024885
#   x=1.200  error=0.06658587
#   x=1.600  error=0.03331481
#   x=2.000  error=0.01586691
#
# h=0.41  |  Total accumulated error: 0.343391
#   x=0.000  error=0.00000000
#   x=0.500  error=0.18416968
#   x=1.000  error=0.10021956
#   x=1.500  error=0.04246402
#   x=2.000  error=0.01653819
#
# h=0.46  |  Total accumulated error: 0.475720
#   x=0.000  error=0.00000000
#   x=0.500  error=0.28416968
#   x=1.000  error=0.12621956
#   x=1.500  error=0.04778402
#   x=2.000  error=0.01754699
#
# h=0.51  |  Total accumulated error: 0.364900
#   x=0.000  error=0.00000000
#   x=0.667  error=0.28007072
#   x=1.333  error=0.06723369
#   x=2.000  error=0.01759595
#
# h=0.56  |  Total accumulated error: 0.452620
#   x=0.000  error=0.00000000
#   x=0.667  error=0.38007072
#   x=1.333  error=0.05323369
#   x=2.000  error=0.01931595
#
# h=0.61  |  Total accumulated error: 0.527540
#   x=0.000  error=0.00000000
#   x=0.667  error=0.48007072
#   x=1.333  error=0.01923369
#   x=2.000  error=0.02823595
#
# h=0.66  |  Total accumulated error: 0.665193
#   x=0.000  error=0.00000000
#   x=0.667  error=0.58007072
#   x=1.333  error=0.03476631
#   x=2.000  error=0.05035595
#
# h=0.71  |  Total accumulated error: 0.711432
#   x=0.000  error=0.00000000
#   x=1.000  error=0.55261956
#   x=2.000  error=0.15881205
#
# h=0.76  |  Total accumulated error: 0.905432
#   x=0.000  error=0.00000000
#   x=1.000  error=0.65261956
#   x=2.000  error=0.25281205
#
# h=0.81  |  Total accumulated error: 1.119432
#   x=0.000  error=0.00000000
#   x=1.000  error=0.75261956
#   x=2.000  error=0.36681205
#
# h=0.86  |  Total accumulated error: 1.353432
#   x=0.000  error=0.00000000
#   x=1.000  error=0.85261956
#   x=2.000  error=0.50081205
#
# h=0.91  |  Total accumulated error: 1.607432
#   x=0.000  error=0.00000000
#   x=1.000  error=0.95261956
#   x=2.000  error=0.65481205
#
# h=0.96  |  Total accumulated error: 1.881432
#   x=0.000  error=0.00000000
#   x=1.000  error=1.05261956
#   x=2.000  error=0.82881205
